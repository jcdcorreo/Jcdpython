# %% [markdown]
# ## GRUPO 4
# ### Cabrera Dávila , Jorge Luis  /   Machacuay Navarro, Juan / Wiillian

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import geopandas as gpd

# %%
df = pd.read_csv('tb_medida_estaciones.csv')
df.head(2)
# Out:
#    FECHA_CORTE  FECHA_MUESTRA        CUENTA            ESTACION UNIDAD_MEDIDA  \
# 0     20230706       20230706  PRESA EJIDOS     CANAL PRINCIPAL          m3/s
# 1     20230706       20230706  PRESA EJIDOS  PTE. SANCHEZ CERRO          m3/s
#
#   TIPO_ESTACION DEPARTAMENTO PROVINCIA  DISTRITO  UBIGEO  CAUDAL07H  \
# 0  HIDROMETRICA        Piura    Piura   Castilla  200104      11.41
# 1   HIDROLOGICA        Piura    Piura   Castilla  200104      56.00
#
#    PROMEDIO24H  MAXIMA24H  PRECIP24H
# 0        11.42        0.0        0.0
# 1        62.00       67.0        0.0

# %%
# Convertir las cadenas de texto a datetime
df['FECHA_CORTE'] = pd.to_datetime(df['FECHA_CORTE'], format='%Y%m%d')
df['FECHA_MUESTRA'] = pd.to_datetime(df['FECHA_MUESTRA'], format='%Y%m%d')
df.sort_values(by=['FECHA_CORTE', 'FECHA_MUESTRA'], ascending=[True, True], inplace=True)
# Cambiar el formato a DD/MM/YYYY
df['FECHA_CORTE'] = df['FECHA_CORTE'].dt.strftime('%d/%m/%Y')
df['FECHA_MUESTRA'] = df['FECHA_MUESTRA'].dt.strftime('%d/%m/%Y')

# %%
df.head(2)
# Out:
#       FECHA_CORTE FECHA_MUESTRA        CUENTA            ESTACION  \
# 14877  06/09/2022    01/01/2022  PRESA EJIDOS     CANAL PRINCIPAL
# 14878  06/09/2022    01/01/2022  PRESA EJIDOS  PTE. SANCHEZ CERRO
#
#       UNIDAD_MEDIDA TIPO_ESTACION DEPARTAMENTO PROVINCIA  DISTRITO  UBIGEO  \
# 14877          m3/s  HIDROMETRICA        Piura    Piura   Castilla  200104
# 14878          m3/s   HIDROLOGICA        Piura    Piura   Castilla  200104
#
#        CAUDAL07H  PROMEDIO24H  MAXIMA24H  PRECIP24H
# 14877        6.5         6.96        0.0        0.0
# 14878        3.0         0.50        3.0        0.0

# %%
df1 = df[((df['FECHA_CORTE'] =='06/07/2023') & (df['ESTACION'] == 'PTE. SANCHEZ CERRO' ))]

# %%
df1.head(50)
# Out:
#     FECHA_CORTE FECHA_MUESTRA        CUENTA            ESTACION UNIDAD_MEDIDA  \
# 784  06/07/2023    07/06/2023  PRESA EJIDOS  PTE. SANCHEZ CERRO          m3/s
# 757  06/07/2023    08/06/2023  PRESA EJIDOS  PTE. SANCHEZ CERRO          m3/s
# 730  06/07/2023    09/06/2023  PRESA EJIDOS  PTE. SANCHEZ CERRO          m3/s
# 703  06/07/2023    10/06/2023  PRESA EJIDOS  PTE. SANCHEZ CERRO          m3/s
# 676  06/07/2023    11/06/2023  PRESA EJIDOS  PTE. SANCHEZ CERRO          m3/s
# 649  06/07/2023    12/06/2023  PRESA EJIDOS  PTE. SANCHEZ CERRO          m3/s
# 622  06/07/2023    13/06/2023  PRESA EJIDOS  PTE. SANCHEZ CERRO          m3/s
# 595  06/07/2023    14/06/2023  PRESA EJIDOS  PTE. SANCHEZ CERRO          m3/s
# 379   HIDROLOGICA        Piura    Piura   Castilla  200104       66.0
# 352   HIDROLOGICA        Piura    Piura   Castilla  200104       66.0
# 325   HIDROLOGICA        Piura    Piura   Castilla  200104       48.0
# 298   HIDROLOGICA        Piura    Piura   Castilla  200104       48.0
# 271   HIDROLOGICA        Piura    Piura   Castilla  200104       48.0
# 244   HIDROLOGICA        Piura    Piura   Castilla  200104       42.0
# 217   HIDROLOGICA        Piura    Piura   Castilla  200104       48.0
# 190   HIDROLOGICA        Piura    Piura   Castilla  200104       57.0
# 163   HIDROLOGICA        Piura    Piura   Castilla  200104       48.0
# 136   HIDROLOGICA        Piura    Piura   Castilla  200104       53.0
# 109   HIDROLOGICA        Piura    Piura   Castilla  200104       57.0
# 82    HIDROLOGICA        Piura    Piura   Castilla  200104       66.0
# 55    HIDROLOGICA        Piura    Piura   Castilla  200104       62.0
# 28    HIDROLOGICA        Piura    Piura   Castilla  200104       67.0
# 1     HIDROLOGICA        Piura    Piura   Castilla  200104       56.0
#
#      PROMEDIO24H  MAXIMA24H  PRECIP24H
# 784       102.50      106.0        0.0
# 757        98.00       99.0        0.0
# 730        90.79      104.0        0.0
# 703        89.29       95.0        0.0
# 676        95.08       99.0        0.0
# 649        92.42       95.0        0.0
# 622        87.50       91.0        0.0
# 595        85.67       88.0        0.0
# 568        77.50       80.0        0.0
# 541        75.00       75.0        0.0
# 514        74.58       80.0        0.0
# 487        79.21       84.0        0.0
# 460        80.17       84.0        0.0
# 433        85.17       88.0        0.0
# 406        79.67       80.0        0.0
# 379        72.67       75.0        0.0
# 352        67.25       71.0        0.0
# 325        57.46       66.0        0.0
# 298        49.25       53.0        0.0
# 271        49.46       53.0        0.0
# 244        43.50       48.0        0.0
# 217        45.25       48.0        0.0
# 190        44.75       57.0        0.0
# 163        49.58       57.0        0.0
# 136        51.96       53.0        0.0
# 109        52.21       57.0        0.0
# 82         55.29       66.0        0.0
# 55         62.54       71.0        0.0
# 28         62.42       67.0        0.0
# 1          62.00       67.0        0.0

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

cuenta = df1['CUENTA'].iloc[0]
estacion = df1['ESTACION'].iloc[0]
#departamento = df1['DEPARTAMENTO'].iloc[0]
provincia = df1['PROVINCIA'].iloc[0]
distrito = df1['DISTRITO'].iloc[0]
unidad= df1['UNIDAD_MEDIDA'].iloc[0]
# Creando el gráfico
plt.figure(figsize=(12, 6))
plt.plot(df1['FECHA_MUESTRA'], df1['CAUDAL07H'], label='Caudal 07H')
plt.plot(df1['FECHA_MUESTRA'], df1['PROMEDIO24H'], label='Promedio 24H')
plt.plot(df1['FECHA_MUESTRA'], df1['MAXIMA24H'], label='Máxima 24H')
plt.plot(df1['FECHA_MUESTRA'], df1['PRECIP24H'], label='Precip 24H')

plt.grid(True)  # Activar las líneas de cuadrícula

plt.xlabel('Fecha de Muestras')
plt.ylabel(f'Valores en {unidad}')
plt.title(f'Datos Hidrometeorológicos - Estación: {estacion}, Cuenca: {cuenta}, Provincia: {provincia},  Distrito: {distrito}')
plt.legend()

# Configurar el localizador de fechas para 30 ticks en el eje X
locator = mdates.AutoDateLocator(minticks=30, maxticks=40)
plt.gca().xaxis.set_major_locator(locator)
plt.xticks(rotation=90)
plt.tight_layout()

# Mostrar el gráfico
plt.show()
